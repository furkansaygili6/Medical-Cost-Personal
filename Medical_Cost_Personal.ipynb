# %% [markdown]
# <a href="https://colab.research.google.com/github/furkansaygili6/Medical-Cost-Personal/blob/main/Medical_Cost_Personal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df=pd.get_dummies(df,columns=['sex','smoker','region'] , drop_first=True)

# %%
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400     False        True             False
# 1   18  33.770         1   1725.55230      True       False             False
# 2   28  33.000         3   4449.46200      True       False             False
# 3   33  22.705         0  21984.47061      True       False              True
# 4   32  28.880         0   3866.85520      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1338 non-null   int64
#  1   bmi               1338 non-null   float64
#  2   children          1338 non-null   int64
#  3   charges           1338 non-null   float64
#  4   sex_male          1338 non-null   bool
#  5   smoker_yes        1338 non-null   bool
#  6   region_northwest  1338 non-null   bool
#  7   region_southeast  1338 non-null   bool
#  8   region_southwest  1338 non-null   bool
# dtypes: bool(5), float64(2), int64(2)
# memory usage: 48.5 KB

# %%
x=df.drop('charges' ,axis=1)
y=df['charges']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=25)

# %%
li=LinearRegression()
model=li.fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.7490732999835243

# %%
df_hata=pd.DataFrame()

# %%
df_hata["y"]=y
df_hata.head(5)
# Out:
#              y
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
y_tahmin=model.predict(x)
df_hata["y_tahmin"]=y_tahmin
df_hata.head(5)
# Out:
#              y      y_tahmin
# 0  16884.92400  25527.375780
# 1   1725.55230   3322.910226
# 2   4449.46200   6636.726422
# 3  21984.47061   3982.642022
# 4   3866.85520   5892.039226

# %%
mean_squared_error(y,y_tahmin)
# Out:
# 36608825.89855916

# %%
mean_absolute_error(y,y_tahmin)
# Out:
# 4211.66121704346

# %%
mean_absolute_percentage_error(y,y_tahmin)
# Out:
# 0.43058934949257105
